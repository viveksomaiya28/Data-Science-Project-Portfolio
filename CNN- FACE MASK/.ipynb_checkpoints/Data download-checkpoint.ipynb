# %% [markdown]
# ## Downloading Dataset

# %%
import kaggle
import os

kaggle.api.authenticate()
downloads_path = 'C:\\Users\\vivek\\Downloads'

kaggle.api.dataset_download_files('omkargurav/face-mask-dataset', path=downloads_path, unzip=True)

print("Dataset downloaded to:", downloads_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/omkargurav/face-mask-dataset
# Dataset downloaded to: C:\Users\vivek\Downloads
